# %% [markdown]
# # Conversational Chatbot with GPT-2
#
# Base code from [this](https://dwjbosman.github.io/chatbot-using-open-ai-gpt-2-transformer-model) blog.

# %% [markdown]
# ## Downloading the GPT-2 model

# %%
# first download the gpt-2 code
# !git clone https://github.com/nshepperd/gpt-2.git
cd gpt-2
# Out:
# Cloning into 'gpt-2'...
# remote: Enumerating objects: 435, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 435 (delta 19), reused 48 (delta 13), pack-reused 371
# Receiving objects: 100% (435/435), 4.48 MiB | 16.32 MiB/s, done.
# Resolving deltas: 100% (220/220), done.

# %% [markdown]
# install requirements

# %%
# !pip3 install -r requirements.txt
# Out:
# Collecting fire>=0.1.3
#   Downloading https://files.pythonhosted.org/packages/11/07/a119a1aa04d37bc819940d95ed7e135a7dcca1c098123a3764a6dcace9e7/fire-0.4.0.tar.gz (87kB)
#      |████████████████████████████████| 92kB 11.9MB/s
# Collecting regex==2017.4.5
#   Downloading https://files.pythonhosted.org/packages/36/62/c0c0d762ffd4ffaf39f372eb8561b8d491a11ace5a7884610424a8b40f95/regex-2017.04.05.tar.gz (601kB)
#      |████████████████████████████████| 604kB 36.0MB/s
# Collecting requests==2.21.0
#   Downloading https://files.pythonhosted.org/packages/7d/e3/20f3d364d6c8e5d2353c72a67778eb189176f08e873c9900e10c0287b84b/requests-2.21.0-py2.py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 9.8MB/s
# Collecting tqdm==4.31.1
#   Downloading https://files.pythonhosted.org/packages/6c/4b/c38b5144cf167c4f52288517436ccafefe9dc01b8d1c190e18a6b154cd4a/tqdm-4.31.1-py2.py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 7.7MB/s
# Collecting toposort==1.5
#   Downloading https://files.pythonhosted.org/packages/e9/8a/321cd8ea5f4a22a06e3ba30ef31ec33bea11a3443eeb1d89807640ee6ed4/toposort-1.5-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire>=0.1.3->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire>=0.1.3->-r requirements.txt (line 1)) (1.1.0)
# Collecting idna<2.9,>=2.5
#   Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 10.5MB/s
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (2020.12.5)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests==2.21.0->-r requirements.txt (line 3)) (3.0.4)
# Building wheels for collected packages: fire, regex
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=70455e9c7df7d59748ce1ef44e77109dc7f7028f7383fa76667d4cb7f94c8a13
#   Stored in directory: /root/.cache/pip/wheels/af/19/30/1ea0cad502dcb4e66ed5a690279628c827aea38bbbab75d5ed
#   Building wheel for regex (setup.py) ... done
#   Created wheel for regex: filename=regex-2017.4.5-cp37-cp37m-linux_x86_64.whl size=534411 sha256=55ff2483ad819a98007aa70a7a50138f1b76516d30de4d100e7e275b32a5a155
#   Stored in directory: /root/.cache/pip/wheels/75/07/38/3c16b529d50cb4e0cd3dbc7b75cece8a09c132692c74450b01
# Successfully built fire regex
# ERROR: spacy 2.2.4 has requirement tqdm<5.0.0,>=4.38.0, but you'll have tqdm 4.31.1 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement requests~=2.23.0, but you'll have requests 2.21.0 which is incompatible.
# ERROR: fbprophet 0.7.1 has requirement tqdm>=4.36.1, but you'll have tqdm 4.31.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: fire, regex, idna, requests, tqdm, toposort
#   Found existing installation: regex 2019.12.20
#     Uninstalling regex-2019.12.20:
#       Successfully uninstalled regex-2019.12.20
#   Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# Successfully installed fire-0.4.0 idna-2.8 regex-2017.4.5 requests-2.21.0 toposort-1.5 tqdm-4.31.1

# %% [markdown]
# download the model

# %%
# download the pretrained model
# !python download_model.py 117M
# or 345M...

# %%
# %tensorflow_version 1.x

import tensorflow
print(tensorflow.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
import sys
# !export PYTHONIOENCODING=UTF-8
sys.path.append("/content/gpt-2/src")

# %%
import fire
import json
import os
import numpy as np
import tensorflow as tf
import model, sample, encoder
import generate_unconditional_samples
import interactive_conditional_samples

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
class GPT2:
  
  # extracted from the source code to generate some text based on a prior
  def __init__(
      self,
      model_name='117M',
      seed=None,
      nsamples=1,
      batch_size=1,
      length=None,
      temperature=1,
      top_k=0,
      raw_text="",
  ):
      """
      Interactively run the model
      :model_name=117M : String, which model to use
      :seed=None : Integer seed for random number generators, fix seed to reproduce
       results
      :nsamples=1 : Number of samples to return total
      :batch_size=1 : Number of batches (only affects speed/memory).  Must divide nsamples.
      :length=None : Number of tokens in generated text, if None (default), is
       determined by model hyperparameters
      :temperature=1 : Float value controlling randomness in boltzmann
       distribution. Lower temperature results in less random completions. As the
       temperature approaches zero, the model will become deterministic and
       repetitive. Higher temperature results in more random completions.
      :top_k=0 : Integer value controlling diversity. 1 means only 1 word is
       considered for each step (token), resulting in deterministic completions,
       while 40 means 40 words are considered at each step. 0 (default) is a
       special setting meaning no restrictions. 40 generally is a good value.
      """
      if batch_size is None:
          batch_size = 1
      assert nsamples % batch_size == 0

      self.nsamples = nsamples
      self.batch_size = batch_size

      my_model_path = "/content/gdrive/MyDrive/Colab Notebooks/NLP/project/"   # "/content/gpt-2/models/"
      
      self.enc = encoder.get_encoder(model_name, my_model_path)
      hparams = model.default_hparams()

      with open(os.path.join(my_model_path, model_name, 'hparams.json')) as f:
          hparams.override_from_dict(json.load(f))

      #with open(os.path.join('models', model_name, 'hparams.json')) as f:
      #    hparams.override_from_dict(json.load(f))

      if length is None:
          length = hparams.n_ctx // 2
      elif length > hparams.n_ctx:
          raise ValueError("Can't get samples longer than window size: %s" % hparams.n_ctx)

      self.sess = tf.Session(graph=tf.Graph())
      self.sess.__enter__()
      
      self.context = tf.placeholder(tf.int32, [batch_size, None])
      np.random.seed(seed)
      tf.set_random_seed(seed)
      self.output = sample.sample_sequence(
          hparams=hparams, length=length,
          context=self.context,
          batch_size=batch_size,
          temperature=temperature, top_k=top_k
      )

      saver = tf.train.Saver()
      self.ckpt = tf.train.latest_checkpoint(os.path.join(my_model_path, model_name))
      #self.ckpt = tf.train.latest_checkpoint(os.path.join('models', model_name))
      saver.restore(self.sess, self.ckpt)

  def close(self):
    self.sess.close()
  
  def generate_conditional(self,raw_text):
      context_tokens = self.enc.encode(raw_text)
      generated = 0
      for _ in range(self.nsamples // self.batch_size):
          out = self.sess.run(self.output, feed_dict={
              self.context: [context_tokens for _ in range(self.batch_size)]
          })[:, len(context_tokens):]
          for i in range(self.batch_size):
              generated += 1
              text = self.enc.decode(out[i])
              return text
              #print("=" * 40 + " SAMPLE " + str(generated) + " " + "=" * 40)
              #print(text)
      #print("=" * 80)

# %%
gpt2 = GPT2(model_name="checkpoint81")

# you must also call download_model.py (see earlier cell) with the correct parameter
# 1558M, best results takes a long time to load
# 1558M, 774M, 355M, 345M, 124M, and 117M
# Out:
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:60: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /content/gpt-2/src/sample.py:65: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# INFO:tensorflow:Restoring parameters from /content/gdrive/MyDrive/Colab Notebooks/NLP/project/checkpoint81/model.ckpt

# %%
result = gpt2.generate_conditional(raw_text="what is two plus two ?")

print(result)
# Out:
# Not a soul.
# <|endoftext|>
# Not a soul.
# I have, uh, His Majesty's orders regarding pipelines. I just not seen anything. I have a message for you, carpenters.
# <|endoftext|>
# I have, uh, His Majesty's orders regarding pipelines. I just not seen anything. I have a message for you, carpenters.
# Oh, I don't know whether you're well connected or not, but I assure you they are. You do know how to use a pipe, don't you. I have some lessons I think you should learn.
# <|endoftext|>
# Merry Christmas everyone. I'm glad to see you again.
# Sure don't look like you been travelling around very much.
# <|endoftext|>
# Umm, Mr. Justin's office. I was coming by to say that.
# Nice to see you again, Mr. Justin.
# <|endoftext|>
# Nice to see you again, Mr. Justin.
# You were very clear on this point quite a bit of talk.
# <|endoftext|>
# Something like that. I mean, are you strictly cutting both tracks and cutting the results of this test ?
# You bet your buck.
# <|endoftext|>
# Say again?
# Yes. I'm making the claim that Canada is using the same amount of PG- stuff that they PG- related supplier South Sudan. And the discrepancy is caused by a discrepancy on label -- a discrepancy which is going to make a big difference in what you say next step with our shipments.
# <|endoftext|>
# And if it leads to any problems for you developing countries or any others, I'd advise you to try China, the South Sudan issue.
# Well, I'll make that right up... Uh, Mr. Rick, can you let me know what you know about the subject ?
# <|endoftext|>
# It's a rough one. As you know, South Sudan has been a hot commodity in the international Oilpatch and is now following South Sudan and North expire into the dilithium. Would it be possible to obtain commercial quantities of PG- 13 precursors?
# With the permit -- ?
# <|endoftext|>
# With the permit -- ?
# -- with the costs with the project and with the attendant environmental risks.
# <|endoftext|

# %%
class Who:
  """A class defining the conversation parties: me, he"""
  def __init__(self):
    self.prefixes = []

  def matches(self,phrase):
    for prefix in self.prefixes:
      if phrase.startswith(prefix):
        #print(f"{phrase} starts with {prefix}")
        return True
      
    #print(f"{phrase} does not start with {self.prefixes}")
    return False

  def get_random_prefix(self):
    return self.prefixes[0]
  
class Me(Who):
  def __init__(self):
    super().__init__()
    self.prefixes = [""]
   
  
class You(Who):
  def __init__(self):
    super().__init__()
    self.prefixes = [""]

# %%
class Conversation:
  
  def __init__(self, prior = None):
    if prior is None:
      prior="""
      You said: "Nice to meet you. What's your name?"
      I said: "My name is Pete."
      You said: "That's an interesting name. How old are you?"
      I said: "I'm 40 years old."
      You said: "Can you tell me something about yourself?"
      I said: "Ofcourse! I like playing video games and eating cake. "
      You said: "I like sweet stuff too. What are your plans for tomorrow?"
      """
    self.suggestion = None
    
    self.me = Me()
    self.you = You()
    self.parties  = [ self.me, self.you ]
    
    self.conversation = []
    
    lines = prior.split("\n")
    for line in lines:
      line = line.strip()
      if len(line)!=0:
        party = None
        for party in self.parties:
          if party.matches(line):
            break
        if party is None:
          raise Exception(f"Unknown party: {line}")
                
        self.conversation.append((party,line))
    self.get_suggestion()
    
  
  def get_prior(self):
    conv = ""
    for (party, line) in self.conversation:
      conv+=line+"\n"
    return conv
  
  def get_suggestion(self):
    who, last_line = self.conversation[-1]

    party_index = self.parties.index(who)
    next_party = self.parties[(party_index+1) % len(self.parties)]
      
    conv = self.get_prior()
    conv += next_party.get_random_prefix()
    answer = self.get_answer(next_party, conv)

    if not next_party.matches(answer):
      prefix = next_party.get_random_prefix()
      answer = prefix + answer
    
    self.suggestion = (next_party, answer)
  
  def next(self, party = None, answer = ""):
    """Continue the conversation
    :param party: None -> use the current party which is currently in turn
    :param answer: None -> use the suggestion, specify a text to override the 
           suggestion
    
    """
    suggested_party, suggested_answer = self.suggestion
    if party is None:
      party = suggested_party
    
    if answer == "":
      answer = suggested_answer
      
    if not party.matches(answer):
      prefix = party.get_random_prefix()
      answer = prefix + answer
    
    answer = answer.strip()
    if answer[-1] != "\"":
      # add the closing "
      answer += "\""
      
    self.conversation.append((party, answer))    
    self.get_suggestion()
    
  def retry(self):
    self.get_suggestion()
        
  def get_answer(self, party, conv):
    answer = gpt2.generate_conditional(raw_text=conv)
    lines = answer.split("\n")
    line = ""
    for line in lines:
      if line !="":
        break
      
    if line!="":
      return line
    
    return ""
      
  def show(self):
    conv = ""
    for (party, line) in self.conversation:
      conv+=line+"\n"
    #print(conv)
    if self.suggestion is not None:
      party, answer  = self.suggestion
      while answer == "<|endoftext|>":
        party, answer  = self.suggestion
        self.retry()
        print("retrying...")
      #print("--> "+answer)
      return answer

# %% [markdown]
# ## Generating answers for evaluation

# %%
import requests

MODEL_NAME = "checkpoint81"
models = ["ncm", "dbdc", "os", "twitter", "cornell"][:]
urls = ["https://raw.githubusercontent.com/chateval/application/master/assets/prompts/ncm.txt",
        "https://raw.githubusercontent.com/chateval/application/master/assets/prompts/dbdc.txt",
        "https://raw.githubusercontent.com/chateval/application/master/assets/prompts/os.txt",
        "https://raw.githubusercontent.com/chateval/application/master/assets/prompts/twitter.txt",
        "https://raw.githubusercontent.com/abaheti95/DC-NeuralConversation/master/MTurk%20Evaluation/MTurk2%20model%20responses/s_cornell_mturk2_test.txt"][:]

# %%
models
# Out:
# ['ncm', 'dbdc', 'os', 'twitter', 'cornell']

# %%
for i in range(len(models)):
  url = urls[i]
  model = models[i]

  print("Dataset", model)

  resp = requests.get(url).text.splitlines()

  answers = []
  for line in resp:
    print("Q", line)
    c = Conversation(line)
    # show the conversation and the suggestion by the ai
    ans = c.show()
    print("A", ans)
    print()

    answers.append(ans)

  with open(MODEL_NAME + "_" + model + ".txt", 'w', encoding="utf8") as filehandle:
      filehandle.writelines("%s\n" % answer for answer in answers)
# Out:
# Streaming output truncated to the last 5000 lines.
# retrying...
# retrying...
# retrying...
# retrying...
# A Declining stars ?
#
# Q Just put me back in the other way .
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A Well, here we are. I got together an old mole in my office, I want someone to complain to .
#
# Q Uh , I' m sure all your spaces are filled for tonight .
# A Yeah, but don't worry about me staying up. There are a thousand theories around here, but I think I've come up with a hundred. Let's just get started. I finished my design, how's it going?
#
# Q Benita Matkudzi ... . . burned to death during a protest rally .
# A And Cadwalader Izzard ... !
#
# Q lnspector Yip , James from the UK .
# A We made a good impression, didn't we?
#
# Q All right .
# A Does Kimura put him in prison for killing that policeman?
#
# Q I' m dead .
# retrying...
# retrying...
# A Then leave me alone  watch this.
#
# Q Newport , ' 88 .
# A Joey  I sensed something.
#
# Q That' s just my style .
# A Oh, it's never bad 'cept women to go out, do some reading about Enzo .
#
# Q Just leave me out of it .
# retrying...
# retrying...
# A I can't switch any more people with you if it's on the line. I broke my ankle .
#
# Q So ... one day ...
# retrying...
# retrying...
# A You miss me.
#
# Q Buzzing
# A Of course you did. Checking back up.
#
# Q We should have some music .
# A No, no! Do you want a song or... You want business?
#
# Q So ...
# A I'll be there, too --
#
# Q Complete .
# A I saw the works. I saw the world burn. I saw "spheres -- fire -- rising and falling -- dashes and ripples -- and rocks -- flowing and flowing again." Julius Caesar, sitting on a wooden throne, an image of Victory standing in front of him, dedicated to the world. Through the years, the world began to look like this. Like a reflection in my twilight hours. I saw the gates of hell being opened to welcome those here to welcome you. The whole universe just waking up. I saw the stars rising and falling again. A vast lightning. A shower. The lining of the tops of the roads. Wallowing on our streets. Pricking our fabric. Locking us up every chance we get. You're right, I've had moments of beauty. I've even had moments of misfortune. I've seen worse.
#
# Q I' il kill Arthur .
# A No you didn't.Hullo, you've already beaten yourself up. And now this Guinness of yours. Hal Winstanley-Kenny. Thank you.
#
# Q Look , fellas ...
# A ) That's why I'm taking one.
#
# Q Thanks .
# A Go on Professor Zuckerman
#
# Q Why don' t you buy it ?
# A Pretty obsessive, huh ?
#
# Q Chip .
# retrying...
# retrying...
# A Next week we'll bag a fucking flag! You men suckers!
#
# Q No .
# retrying...
# retrying...
# A You tell Nawcet we go through with it?
#
# Q Brett , give me your pen .
# A Give you mine. I'll ask you what you want back.
#
# Q It' s all over .
# retrying...
# retrying...
# A Sounds good to me ... Mookie.
#
# Q You' il stay down !
# A You see you keep a low profile. Your confidence's a constant concern. I see that all through the cards. You're tough on the outside. You're more concerned with what's going on inside.
#
# Dataset twitter
# Q when you find so you decide to stay in her class
# A I think the following is very interesting.... I'm going to be arrested when she gets back...
#
# Q not a single reporter noticed that hillary's entire staff was on death's door and a doctor was following her around?
# A Oh sure. She watched Bruce spazz out with a Geddy Lee out of a hat on a recent Saturday. Probably any veteran of the Branch Davidian scene who happened to stop by.
#
# Q jim schwartz has faced 2 teams as defensive coordinator. both starting qb's have left the game injured.
# A By the time the sun comes up it'll look younger and wrinkly. This is about his time.
#
# Q go gettum jared!
# A Yeah, I got it!
#
# Q arsenal didn't deserve to win either so?
# retrying...
# retrying...
# retrying...
# retrying...
# A What I mean is, your questionnaire was highly critical and thorough.
#
# Q if you sit this election out and trump wins by a few votes, many people are going to be dealing with that reality for their entire lives.
# A I also warn you, these are no time to waffle. Please. We've been through this together, Brother. Maybe it is time this election was changed.
#
# Q dinner cookie. the very second cyndi met david. , this pic means the world to me. you're the best.
# retrying...
# retrying...
# A Applejack, whatever dandelion tree you figger, do you still love him?
#
# Q 3. yes, the romance is a total failure.
# A Yeah. I mean, I love your comics. I mean a certain way, but I hate writing comic books. I'm obsessive about my comic books. You know I love my books -- judge them by the covers and the art direction, by the art direction and the sexy stuff.
#
# Q if i wanted to spend my time arguing, i'd call my mother. i come to twitter to laugh and send out random twat shots. you know, to have fun.
# A You would have to laugh at me.
#
# Q reading now. this is absolutely fantastic.
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A Yeah. I like.
#
# Q gente acabei de ver o cachecol nós somos fodas! wendigo all over again
# retrying...
# retrying...
# retrying...
# A You ought to eat first! You're in so bad, you ought to be drenched. In fact, when I came out here with Casanova, I became so tired I didn't dare discuss anything important with him.
#
# Q classic to try and spin an innocent protest into making it seem like he was going to be assassinated.
# A No... you're not. Now stop! Just stop wheating maniacal, you're going to identify me.
#
# Q ‘she’s a great role model’ sturgeon breaks protocol to urge americans to back clinton
# retrying...
# retrying...
# retrying...
# A But you don't know when you'll be on
#
# Q i would talk your mom into swallowing instead.
# A Women are so afraid of men. What if... they put the fear of death behind them! They want men they get with beads and panties on! Fat little stones. Phallic symbols. Do you understand me? There is no "right" or "wrong" way to eat! You want meat and you want to get it fast!
#
# Q i just saw this. this is a good tweet.
# A Augustman's still getting there. It's just so obvious.
#
# Q amazing how high emotions go once you make subscriptions visible. but paid updates aka "hidden subscriptions" cause old app breaks are fine.
# A OK. I guess a split second or something cleared it up?
#
# Q maybe she doesn't do windows. directed her maid to print out classified materials via
# A Reporters.
#
# Q could care less about celebs i care abt the mccarthyism against ppl w/ differing opinions &amp; irresponsible blind eye to hrc's crimes
# A I wantesses an "I don't care about you!" education masti's entirely unnecessary, i'd wjiight wantesses an ideal of people of knowledge
#
# Q nah you're not the jazz are not that good in my opinion either
# retrying...
# retrying...
# retrying...
# A I'm copin'
#
# Q i just got a press email for a bike lock kickstarter campaign. email said i am getting it because i previously wrote about fashion.
# A Not too different from the way I read it, don't you think? In Fashion: *Misery*, Steph Treadgold is trying to seal up a tax loophole for the super specialization of Dorset. Of course, while the Dorset in question has always looked and sounded fascist, hey, I live in New York so maybe I can be a little less fascist, y'know.
#
# Q anyone remember me tweeting before the season saying "i just don't buy the nyr being bad this year." desperately trying to find the tweet.
# A I digress. You know, Jeffrey did delivery on a suicide note, wipe the slate clean at some point and now I think he means it real well. You got anybody telling you the best part is you have made a disciple of yourself.
#
# Q is it over yet? is it safe yet to come back on the interwebs?
# A Very safe. I'm concerned about that, you know.
#
# Q i'm gonna finish my essay and then go to the gym
# retrying...
# retrying...
# A Not more. You can skate if you want but you should be doing a farning routine by the end of the week.
#
# Q in this case, trump is right. the fbi investigation was rigged.no grand jury; immunity deals; fbi destroys evidence.
# retrying...
# retrying...
# A Well who the F.B.I. am investigating is basically a monopoly. Gregory Cochrane, the Feds; Tom Ridge, the DEA; Larry Oh!
#
# Q pennsylvania is focused! election day is 3 weeks away!
# A For what? Oh yeah - election day -- I'll put you in touch with my folks, they'd get into some trouble!
#
# Q ha! that was recorded in 2002 years before it was released. had 4 tracks, a hand held microphone, &amp; good weed
# A Sweetheart, I got that....
#
# Q thanks for the invite tonight.....
# retrying...
# retrying...
# A I don't want to open tonight.....
#
# Q the world turned upside down: hillary clinton defends reagan and wants to stand up to the russians. the gop candidate, not so much.
# retrying...
# retrying...
# A What did he get?
#
# Q ty chef for that delicious episode on how to make spaghetti
# retrying...
# retrying...
# A Oh, well, if I'm not by now right from the kick-ass date, and you're not, then you might want to reconsider. That was an evening.
#
# Q started watching on youtube. haven't finished but i'm seeing your point.
# A Well, I guess this time the main focus's gonna be our problem.
#
# Q just seen this on facebook, thought it was a great little read.
# retrying...
# retrying...
# A Hope you all had a wonderful day,
#
# Q courtney kube reporting from the pentagon on this issue: advance notice helps civilians to prepare, not just isis.
# A Nobody's saying you're the nut. You don't surrender, you're not announcing that the qual release ray rabbit either.
#
# Q that is decidedly not what you've been doing. wanting to tear down a working system is unstable.
# A I feel like I've been doing a fairly uninterrupted job over the past hour.
#
# Q . i'm pretty sure chris wallace got the remaining 6%.
# retrying...
# retrying...
# A Then get this second one for chris.
#
# Q even though is a disaster and my own husband (who has raped multiple women) has admitted that, i still stand for it! no change!
# retrying...
# retrying...
# A It's true! And believe me, the Italians were making billions selling ov bese!
#
# Q contempt for hillary...sure i despise her ,her lies and what she represents: corruption. apparently stuff you like..
# A You do too. Adenauer loved his Hutu brothers.
#
# Q how big the state of california is compared to the east coast
# A Jesus, man.
#
# Q if ur skinny, pls stop saying you're fat cause you make girls with a little extra chub appear obese
# A No, of course not, please.
#
# Q (hint: he's lying on *every* issue. )
# A No offense. But I do believe eyes are part of the intelligence -- and-and that this new toolkit is a logical extension to both."
#
# Q anyways good night! loved debating w and will pray fo u
# A Nine o'clock I know. Uhh lean on the duct. Give me some time to get a feel.
#
# Q i love my new hat
# retrying...
# retrying...
# A I'll wear this
#
# Q hillary is pedestrian and over-programmed, but never made a notable mistake across 3 debates
# retrying...
# retrying...
# retrying...
# A Hi Karl. Could we talk?
#
# Q when we are experiencing fear, anxiety, and/or anger (so imagine all three), our ability to empathize takes a hit.
# retrying...
# retrying...
# retrying...
# A How did your in-vitro research devolve into your demonology?
#
# Q words cannot express my excitement for on 4am baby!!!
# A Men in dark clothing have all day; you don't want to be seen with any girl of your choice.
#
# Q the facts are incredible too wow
# retrying...
# retrying...
# A Well, he reminds me a little bit of you, Jack and So you say, that one thing we like in each other - unity
#
# Q just landed in ohio. thank you america- i am honored to win the final debate for our movement. it is time to…
# A You will bring peace to Mongolia?
#
# Q you downloaded some weird shit... has never happened to me
# retrying...
# retrying...
# retrying...
# retrying...
# A So more than likely you'll have to take up something else, which would be swapping outfits.
#
# Q sure it does. idf ass…
# retrying...
# retrying...
# retrying...
# retrying...
# A Just wanted to see how you're doing.
#
# Q consumerism wants us to give up on our individuality and hate ourselves so we're constantly trying to ~be~ something they are sellin to us
# retrying...
# retrying...
# retrying...
# retrying...
# A Whose side are you on?
#
# Q sorry, everyone. we've been wrong all this time. fact checking isn't what matters. this guy's anecdotal life exper…
# A Mr. Brody, this guy is quoted all over the place, hears voices cause he's going to Baltimore,', and it's not him. This is NOT Berger, it's someone else. I can confirm that. same thing, same PhD, same Toronto police force. There was a dinner-club riot in there two months ago involving fourteen people. booby trap, body double locks, fake eyeballs, bullet holes, and slightly retarded, ratty girl named Naomi. suicide note. self-extinguishers.
#
# Q unbelievable! hillary told world response time 4 launching nukes! ... by via
# retrying...
# retrying...
# A ~twenty, thirty, one, two...
#
# Q she handed hillary a debate question ahead of time. bernie supporters care
# retrying...
# retrying...
# retrying...
# retrying...
# A if it surprises them when it comes. ey. .... and when it comes they dig
#
# Q if by funeral, you mean resurrection, then yes. can't wait to see your hype video praising it
# retrying...
# retrying...
# retrying...
# A Here I am, outta my frigging maudlin-soul, and -- I swear I should've been in charge this time. All somethings go, always, and O.J.'s always go.
#
# Q poll: who won the final presidential debate?
# A Good work, Craig. I really love it, I love it...
#
# Q therefore, have to trust they will use wisdom and judgement to come to right decisions on unknown unknowns
# retrying...
# retrying...
# retrying...
# A They must pay the ransom!
#
# Q you're a hard man to find when you want to be...
# retrying...
# retrying...
# A Then what about the other one?
#
# Q in honor of tonight's here is 17 year old sam ~acting~ as columbia complete with a sexy corset/sports…
# A ...Huh?
#
# Q this is what happens when a republican nominee can't even hold the line in traditional swing states
# A ...What do you call Washington when her party strangles the Democrats and she wins? ...I've learned the foreign policy of a George W. Bush is telling us about Washington's foreign policy. She will offer generals a unique curriculum. -- Churchill exposed us to this in Europe. Begin to notice you talk about this in circles. ...Once I'm in the room, you thing, hurry to meet me.
#
# Q *wipes tear* guess i'll be doing this for the final time.... "is this the nx?"
# A Hie we need to swing.
#
# Q sry i'll take allan lichtmans political science predictions over bought &amp; paid 4 network polls
# retrying...
# retrying...
# A Carlos rubbished that historical inaccuracy; at best. at worst .. ..
#
# Q initial thoughts. seems like a solid idea for a console. i wonder how much of a performance hit going mobile will be?
# retrying...
# retrying...
# A Mmm. Money. It'll be fine. I'm sure that's half full. Look, a microphone. More bass. Probably your "cornet" for pay. We'll see.
#
# Q well for now they nailed it. we may come to find that there's little toads on hamster wheels for a processor and that would be
# retrying...
# retrying...
# retrying...
# A Something else! Somehow I hear the lists ring louder than the dogs. My door here and I wander into the sweat shops over and over. Dower here and Dower there. y'know they do count - each mark representing something. a dog in the desert, or...
#
# Q thanks for the shout out! to note we're in charleston, sc not nc (we're very proud of our hometown lol)
# retrying...
# retrying...
# A I'm sorry. You're being ridiculous!
#
# Q blaming india lets em to feel good, and ignore horrific reality at home.
# A What is it?
#
# Q how to build a sb winner. need a top 2 unit on either off or def in dvoa. neither side of roster close right now for bucs.
# retrying...
# retrying...
# A EM, Eltz, reelz.
#
# Q fancy! co-conspirator in mangano complaint allegedly paid for a massage chair for mangano &amp; limo service for vend…
# A What about this?
#
# Q very clear now that uk membership of single market a gateway to indyref2 in scotland. time to dynamite the bridges. they've forced our hand
# retrying...
# retrying...
# retrying...
# A You're chasing a man-eater relationship ? a false identity ?
#
# Q mary grace needs to stop trying to fuck the local priest
# retrying...
# retrying...
# A Well, grace said it was one thing to strip down to a Sunday school uniform for me, but when it comes to "gentle revenge", I'm all for it.
#
# Q it's useless to snort playdough. believe me.
# A You're old, huh?
#
# Q throw this in the mix
# A We want your sanity further into the future. Your green card has already been issued.
#
# Q island folks got caribbean magic in their loins.
# A Basically....I think they've brought back to life the glamour of civilization.
#
# Q but, time will tell how her 3 years affects public perception of her... and whether she even stands a chance of winning the office again.
# retrying...
# retrying...
# retrying...
# A You enrich the shooter profits. Engage a few architects and renderings. Don't overwhelm her with complex representations of her own anatomy. Don't turn that very fine knife into a performance rather than attempt a comeback. Long live Jefferson Beauregard. My condolences.
#
# Q on everything i just put my head down and walked back into the office
# retrying...
# retrying...
# retrying...
# A You were leavin' staff? Are you planning on follow me around the building that far?
#
# Q can't wait to see who can be the first to drop the nasty woman ep. ? ? ?
# retrying...
# retrying...
# retrying...
# A Thank you for the information. Maybe she's out here another people.
#
# Q ugh, my cable modem internet is out this morning &amp; now i can't find the dilbert parody i tried &amp; failed to retweet that the app recommended.
# A Haven't you noticed the drop in traffic lately?
#
# Q my fav is still commie jen
# A I like to get fried cat food whenever there might be a shower. Too many local restaurants have fried food on the walls. Yukon Poodle joint's a feast. Round Pew's is like a dumpling, fluffy, gooey, pliable.
#
# Q i just saw this on tumblr, and it may be the worst thing i've ever seen.
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A He said that?
#
# Q would u take your child's life to save your wife's?? aren't parents suppose to protect their children.
# retrying...
# retrying...
# retrying...
# A She didn't report it.
#
# Q i was distracted and i potted the 8 ball
# A Will will sniff that
#
# Q got offered jeremy maclin for allen robinson. ?
# A Slow home? We got him tomorrow night.
#
# Q wikileaks drops podesta mail drip, drip, drip continues following hillary's eye-crossed disaster debate last night - bye hrc
# retrying...
# retrying...
# A Watch it. Watch it now.
#
# Q false information
# A Could you tell us something?
#
# Q while "nintendo switch" is an accurate name for the product, i got accustomed to calling it "nx" and was okay with that being the final name
# A Then you didn't care.
#
# Q it is through the mass percolation of grossly farcical eurocentric lies that allows schools to serve as surrogates of power &amp; suppression.
# A But, I am aware of it, there is something deeper percolating in this community, &amp; both here in London & spreading &amp; in general. Do you believe that?
#
# Q and we're off! to phoenix then albuquerque!
# A Trainer, I don't trust you, either.
#
# Q it's almost like kanye just realized jay was using him and doesn't need him anymore.
# retrying...
# retrying...
# A That's him next. As soon as he gets court-ordered out, he's gonna look for nudes on his own.
#
# Q big scary cve
# A then me and who are you...
#
# Q terrified that trump will be a challenge to hillary and draw broad support from unions.
# A A long way to go before he stumbles into town before he's established himself as a serious contender... or "ancillary contender".
#
# Q in australia... driving the coastline, reminded of the beauty found throughout the world &amp; renewing my commitment t…
# retrying...
# retrying...
# A Oh, yes. Thank you. You've done a great job on those suitcases. Actually, I had one bagful old...
#
# Q i want that deep inside of me.
# A What?
#
# Q i just ate turkey :o
# retrying...
# retrying...
# retrying...
# retrying...
# A What's left at Camp Belle Raines?
#
# Q moderator: hillary paid $225,000 by a brazilian bank for a speech that called for “open borders.” that’s a quote!
# A In the UN's eyes, "open borders" is absolutely the word. So why were we allowed to buy products in countries with open borders?
#
# Q awesome! the mothers of the movement won't be around to see the effects of it in 20-30 years only we will, congrats bro
# retrying...
# retrying...
# retrying...
# A Good luck then, Mister Koala
#
# Q we build apps remotely!our portfolio ☞ let’s talk :) email to ☞ leads.com ☎ (212) 209 1537
# A That's all I thought.
#
# Q want access to crooked hillary? don't forget - it's going to cost you!
# A Oh really, Fezzik, I did a job for them and now I have to dump that truck full of oil into the sea.
#
# Q to livestream my concert tonight or to not livestream my concert tonight?
# A Thanks. Sondheim's the only one who thinks I wanna live here. We stuck with Eddie Swalm -- you know who.
#
# Q i feel like it did make an impact. just might not be enough for this election (unless some really juicy stuff gets leaked)
# A We should've asked Justin.
#
# Q obama says his departure may fix what ails obamacare
# retrying...
# retrying...
# A What did he say?
#
# Q how do you find that on properties?
# retrying...
# retrying...
# A Feedback -- uh, ma? Mrs. Powell!
#
# Q does this work?
# retrying...
# retrying...
# retrying...
# A No.
#
# Q if you compare apples to apples it looks like this:
# retrying...
# retrying...
# retrying...
# retrying...
# A That's a mistake. You talk with pride about our differences, about the world as we know it.
#
# Q today i'm starting a new job at . it wouldn't be a new job without a blog post, would it?
# retrying...
# retrying...
# retrying...
# A Oh. well, it's really a new job. At least I'm working... least I can take this! I'm coming by...I'll come by and tell you where to find you.
#
# Q i can't make any sense of it. are there similar examples out there to compare this theory to?
# retrying...
# retrying...
# A Maybe, sounds like fun.
#
# Q yes finally i can say it yes.
# A Oh I got howls just like that! I know it sounds crazy .just kidding .I mean the thing is, after my mom died I had to stuff all my crap away and think of nothing else .And they gave me this coconut oil as a gift. So after that I just liked sitting in the dark like an animal. I thought, "Maybe I'll be surprised."And as a bonus, I got to soak in the sound of my mom's voice doing the planting of boughs.
#
# Q 7th &amp; bryant was closed until a few min ago due to a suspicious pkg. hoy! jamba's open now.
# A I don't believe it.
#
# Q i only rate as a "mauvais homme," which doesn't sound dastardly enough.
# A I love you, darlin'. I know my life has still plenty of things to do, even if it's only to raid sea creatures. I wouldn't take much for overpriced soft drink, either.
#
# Q this is as close as the news media is allowed to get to the scene of a fatal fire northeast of weeping water in rur…
# A Alan, what could be purchased at these desirable locales? And where are we transmitting to 'undercover' federal agents? It was only a matter of time until this happened into town and into the peripheral vision.
#
# Q megyn kelly grills dnc chair on sharing town hall question with clinton camp
# retrying...
# retrying...
# retrying...
# A It's not gonna happen.
#
# Q who won the debate ?
# retrying...
# retrying...
# retrying...
# A Oh, -- He's an awful clever guy.
#
# Q a child in pakistan polishes shoes to earn a living pic via
# A Oh but he be gone for a couple months then get back to eating... to where? Thailand?
#
# Q “please don't interrupt the script.” – living life according to the scriptures
# A You can tell that to them! Okay I'm finished.
#
# Q (with subscription support plans ). but yeah, that's great. would love more payg in b2c. everyone chasing that recurring revenue.
# A Hopefully, you're getting a couple years for that.
#
# Q about to go home and make something in my new crock pot because i'm a fucking adult.
# retrying...
# retrying...
# A What are you asking me for? You're asking me to take her out tonight, not tomorrow! Jesus Christ!!
#
# Q total bs article my 400 meter times always slower after cigars many cancers associated w/ cigars
# A You on a TV talk show?
#
# Q approved repub. nominees for scotus.
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A Look, I'm not totally responsible, but you're just like...
#
# Q i'm no longer replying lol
# retrying...
# retrying...
# A That's alright... 'Cause I'm a little pissed I wasted all my time.
#
# Q china along with north korea will easily dominate the area and will sink japan &amp; south korea in a minute
# A And then it will not look 'like' us!
#
# Q i hate when people think i'm playing hard to get, i'm not playing hard to get i just don't like you lol
# retrying...
# retrying...
# A It was just an accident.
#
# Q why christian leader jerry falwell jr is standing by trump. in his own words:
# A That's where you cross the line between honorific and superstition. First it was a spear, now it's a name --
#
# Q doesn't matter how much autonomous tech they develop, they won't own the means of manufacturing the cars
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A ...I think we both know by then that Daikowitz galvanized the whole industry here. And he took their voices out of the crowd. Simple, understandable, found a way to sell them, made a spectacle out of himself. Victory was not in his blood. Remember, however, that not everyone he alienated was in his company. He was Moebius. I heard you say that.
#
# Q killing it on with she has solid thoughts and does her best to keep it balanced. the best fox has right now
# A Doesn't bother you' t I know you better?
#
# Q hillary and donald seem to be getting along. chatting away with a cardinal dolan dmz at the al smith dinner.…
# retrying...
# retrying...
# A She knows you had a few drinks. And... and Mavis the roadie. I think She piqued the interest of john leeman!
#
# Q its dissapointing when the promotion has been so great &amp; the core game is a step up
# retrying...
# retrying...
# A So you just won't tell anybody what you did. Why? You're taking a definite step back.
#
# Q fundamental difference between trump wealth &amp; clinton wealth. trump created value to get rich. hillary sold access and favors to make $!
# retrying...
# retrying...
# A Whenever you start something important, quickly - with or without notice - are we supposed to follow it up with an explanation?
#
# Q so my flight was cancelled, and because booked me on ana for my connection i'm stranded in tokyo without hotel.
# retrying...
# retrying...
# retrying...
# A ...I don't know Hotel Tokyo is seven hours away, I should go somewhere faster.
#
# Q shoutouts to and and you guys are the current generation. keep playing and keep winning
# retrying...
# retrying...
# retrying...
# retrying...
# A yeah... chances are good your not gonna win any of those
#
# Q there's a medium of picking and choosing the things that are most entertaining for your characters
# A I'm curious. And what is your favorite theater of yours?
#
# Q who's been to clyde fraziers?
# A Oh yes. Very few musicians do.
#
# Q a tortured life.
# A Is that the truth. You did something to him... grievous injury?
#
# Q improvisation 27 (garden of love ii) by wassily wassilyevich kandinsky (1812)
# A What the fuck did you bring?
#
# Q no you said i am a muslim without knowing it so you might think hillary is a muslim too right
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A If you say yes, how will you know he is a muslim?
#
# Q prophet muhammad freed the slaves, gave women their rights, condemned racism, and forgave ppl who harmed him and other muslims
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A So. State your sense of history here... we're going to go talk to the Free Negroes to find out if they're hurting the Indian. To find out, we're going to do some digging...
#
# Q he was safe and you know it
# A I think I understand... you want his data, just get it. I'll do the trunking.
#
# Q quit showing off, vereen. -ma
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A But really... we just got to see what you mean! That was for a long term project... " pygmies! "
#
# Q let's help all... except the unborn, the elderly, those who disagree with me., etc.
# A Fifteen daughters... regarding all paternity. And Baraka, seventy-five. There is no one 'pin'... more.
#
# Q i have been on twitter for 2 years now and i thank all of my friends and followers who have stayed with me :)
# A There were deranged cyber police. Around that time Esau sent the following threatening telegram to my friends: "Im back. I am watching you trying to be a good kid but it is evil. "
#
# Q so, can i send you my measurements? (i don't wear lbds.)
# retrying...
# retrying...
# A Deodorant?
#
# Q there is no us election. there is power consolidation. rigged primary, rigged media and rigged 'pied piper' candidate drive consolidaiton.
# A Your notion of power in this country is a mutation of nanobot.
#
# Q watch hillary clinton's full remarks at the al smith charity dinner
# A No, scream Mac's face.
#
# Q tonight in san francisco at harlot san francisco with my perfect driver music crew
# retrying...
# retrying...
# A Louisa?
#
# Q writing a check for your seed round immediately
# retrying...
# retrying...
# A ...time to tighten things up.
#
# Q i would have fucked him the fuck up if he ever laid a finger on me or any girl period. his friends are fucked up fo…
# retrying...
# retrying...
# A No I don't have to. And I'm a certain man. I KNOW period. Now all you need to be jealous is you want more shit than you're willing to pay. I want to take a slug to Domini. I want to let her know I've spoken to Lo and Uncle, and I'm not satisfied unless I have some fucking evidence of fucking consent. She knows her way in to the bathroom, and I have some kind of photographic evidence to prove to her that her friend is fucking her. I haven't invited her anywhere, never mind that she's a chick. I should have come up with some fucking reason as to why you went out with Ruiz. I have no fucking reason, anyway. I ain't had it with Mickey, and I've never fucked him. So I'm gonna fucking wait and if I can wha't know, it'll be be I one-fucked-up. Somebody came in the bathroom and fuck me. Like they did last night, don't ya think? Jesus, Ruiz. Yes you did. And you absolutely DID fuck him up, now settle down. I asked you part of it. I said do it. Now. If you don't fuck him up, don't even think you'll fucking dare to fuck him. Don't bitch around unless he tells you he's alright. Don't dog your little self like you bull fiddle. If you fuck him up, it's the end of it. Now. I appreciate you help me. That's the bottom line.
#
# Q lets play zesty
# A Rose, you must answer "yes" to this
#
# Q jake taylor should have been hitting 9th in that lineup. not 2nd.
# retrying...
# retrying...
# A Three, single... Jake... You were winning.
#
# Q i want more specs before i think of purchasing it. what do u think? …
# A Not now, Leonie.
#
# Q it's a damn shame re-reading some shit
# retrying...
# retrying...
# retrying...
# A Here's where I'd like to buy you a drink, the other night, under the table, something blood-red and glorious, something dry and something unadulterated
#
# Q congratulations to our new national security advisor, general h.r. mcmaster. video:
# A Wait a minute...
#
# Q watch: dwayne johnson calls cm punk live in ring after 'monday night raw'
# retrying...
# retrying...
# A Where?
#
# Q why are and i still up? it's late, for god's sake.
# retrying...
# retrying...
# A Maybe not. But I just gotcha-high and wild about Danny and Grendel and Reynard -- all of this -- and it's all on me, you know -- well, without me -- you know.
#
# Q .'s game plan this week: get ready, retail could be a blood bath
# A The Pest Control Room...SCHMUCK!
#
# Q where historic forbes field meets downtown pittsburgh.
# A My lawyers just moved to Denver. I'll have my mustache with me in a couple of weeks too.
#
# Q your performance in was a stunning piece of apologist theater. equating antisemitism to balls and strikes...
# A One more thing: in your statement on the Jewish barricade to congress...
#
# Q comrades of color: east germany in the cold war world
# A ...exactly the "yea"?
#
# Q jw president was on this morning discussing trump's weekend trips costing taxpayers millions
# A LaPlante while she stillpless humiliated Donald Trump Jr. by coming forward and telling Buzzfeed media he'd talked up Kelly
#
# Q come hike the ; discover " in the tallgrass" via
# retrying...
# retrying...
# retrying...
# A Shit.
#
# Q nyc'ers - what is your favorite nice lunch spot very near 18th/6th ave?
# A Patties and soup?
#
# Q if you see anyone on the same tour they're 99% gonna perform the same setlist..
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A No woman on that bus ever thought ...when?
#
# Q this globalization impact is the engine of conservatism's descent into fascism: mapping nationhood to culture, cree…
# retrying...
# retrying...
# A I keep being described as the outsider. My father and uncle, their brother and sister, lab coats, buildings of unparalleled beauty, posturing, ambition, understanding. I keep wondering to myself gee, why me?
#
# Q why is shabbaz in this. nyk give crumbs for a young bench scorer. not enough back.
# retrying...
# retrying...
# A I shall donate the money to the memory of these two deaf persons who lost their friends when everything went black for years -- dear Frankie garland the Japanese pair.
#
# Q we ain't playin..gonna work hard today. slimetime fornadine
# retrying...
# retrying...
# retrying...
# A I just don't see no life for it.
#
# Q i don't really agree but i support your excitement &amp; launching!
# A Oh, my Lord- it's you, your need to be king &amp; that's why i like to see you win.
#
# Q you have proven how real of a friend you are
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A No doubt doing you injustice today will draw the ire of your mother, if you trip off once in awhile. But if it weren't for her, Bernie wouldn't be a McKenna at all. Teacher and student, friend and foe, I am as well-protected as they come.
#
# Q an avocado cost 5 bucks at giant food.
# A Mock me.
#
# Q bull captured after wild chase through jamaica, queens
# A "White Trash," is pretty lousy, but then what is Gwyneth Paltrow? I suggest you read Sir Arthur Conan Doyle and listen to what he wrote. He's full of metaphors and metaphors of longing and anxiety. I warn you, my own line of thought is bizarre, totally out of date.
#
# Q eric church sam hunt jake owen lee brice and jason aldean im fucking ready for route 91 holy shit
# retrying...
# retrying...
# A You run that today. You make them. Eight of ya with some bullshit.
#
# Q a fair point. but with cambridge analytica and the like, these days just about anyone with money can get unparalleled (in history)info
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A Only if you made it past this. Does she stand out as a somewhat amusing visual parlor guy? Or do you go for the romantic? Huh? Waftah!
#
# Q a4 of course this guy was really colorful:)
# A And the fur, and the Oh's and The Ohs.
#
# Q all joking aside, i hope he can turn them around. i would love to see a cavs/lakers finals someday.
# retrying...
# retrying...
# A Nothing much ever happens in town.
#
# Q spicer says priority is to deport people in u.s. illegally who have committed crimes.
# A That sounds fine to me. Let 'em come here and take over.
#
# Q you can take the boy out of cambridge...
# retrying...
# retrying...
# retrying...
# retrying...
# A I didn't do that...Goddamn it!
#
# Q i’m not certain, but i think an intl wire transfer involves a voodoo spell that requires 3 confirmations to process and a carrier pigeon.
# retrying...
# retrying...
# retrying...
# A A carrier pigeon? And no one else associated. Someone on the team is somewhere else.
#
# Q update: it ended the way we thought it would.
# retrying...
# retrying...
# A I got scattered across the world. One of our pods's going to freeze out of orbit after I kill all those nanosleepers. I plan on making some kind of beef.
#
# Q literally just happened to me, failed tf out of my exam just now :)
# A I would -- Agreed.
#
# Q yes. national health insurance would make it so much easier to start a small biz. that would help revitalize the mi…
# retrying...
# retrying...
# A This is just survival; it's not all about luck, either. I mean, I'm not stupid, I've been watching someone else. If you don't start moving soon, we're gonna make ourselves a million for revo.
#
# Q i didn't vote on a false premise so stop trying to speak for me. you can only speak for yourself nobody else.
# retrying...
# retrying...
# A I'm sorry. very sorry.
#
# Q rss "republisher" to twitter, à la twitterfeed? google feedburner? looks hideous, hard to config but works.
# retrying...
# retrying...
# A Do not engage with other republers, and do not talk about the same republer without their permission.
#
# Q school asks teachers to take down pro-diversity posters, saying they're "anti-trump"
# A I didn't expect to see you again.
#
# Q mitch kupchak is useless without jerry west. horrible horrible horrible gm.
# A ...he is not legitimate kupchak mate!
#
# Q asking the important questions tbh
# retrying...
# retrying...
# retrying...
# A Dave. Yeah, he's great. But I can't go out on tangent and talk shit without him.
#
# Q you’ve seen everything already
# A No! No, no, no, no! What?
#
# Q it's the responsibility of educators to provide resources to allow students to expand their knowledge, &amp; that includes about current events.
# A You just aren't going to do your fucking job on this, Charlie.
#
# Q has paid asis for this webinar?
# retrying...
# retrying...
# retrying...
# A Yes!
#
# Q landed in sydney for 1st-ever visit of an israeli pm to australia. thanks for the warm welcome. i'm far from israel…
# A External links. I guess they're all spelt differently.
#
# Q well me being a christian i am torn between this , i believe in trump , we are 20 trillion in debt. jw
# A I am 16 but all i can think about is father and God and he told me that we still belong in hell.
#
# Q hi. i am trying to read 100+ books this year, and i need your absolute top-tier recs around 200 pages.
# retrying...
# retrying...
# retrying...
# retrying...
# A For a practice session.
#
# Q girl i'm throwing a massive rooftop party in honor of national moscow mule day ... friday march 3 .. come !
# retrying...
# retrying...
# A optimum.
#
# Q flags doesn’t imply bitfield to me. why does that imply bitfield to you?
# A  about that stuff about Hartwell not knowing what's going on Guaranteed for Julie parascribed stayed but women don't know all the secrets of the streets.
#
# Q well they're all the same so..
# retrying...
# retrying...
# retrying...
# A What are the back and sides?
#
# Q trying to small talk w the squad like
# retrying...
# retrying...
# retrying...
# A Hello Millionaire Wang.
#
# Q do it! see hamilton, donate to . it's a win-win-win situation!
# A Have at it.
#
# Q he's a killer blocker. perfect backup te and short yardage lead blocker
# A Why?
#
# Q warrentonka is a "do as i say, and not as i do" persona, with her little tomahawk and coup stick.
# retrying...
# retrying...
# A I've been thinking about that...
#
# Q cop mizan...site of a terrible green on blue attack shortly before my sqn got to zabul. we never did find the guys…
# A Where the hell have you been?!
#
# Q this tweet will be plagiarized, i just feel it
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A I can h...
#
# Q he should bring mike back.
# retrying...
# retrying...
# A Sure. Real good huh...
#
# Q i'm saying though... haha. we hitting our mid 20's. who has time for games anymore!? lol
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A I don't wanna be trippin' on you like you raffinates. What am I supposed to do? KILL me and run?
#
# Q rt if you would like to see me with my own show?!? let's make it happen
# retrying...
# retrying...
# A DEUSEN  Yeah, okay, let's make it happen. You're welcome to come and fuck your friends up. You want to be a part of what happens to that body? You want to know? You're welcome to gore your guests... What is this show you callin'?
#
# Q sooo, i've been thinking about this and i want in into
# retrying...
# retrying...
# A I'm okay. Look, this is my deal with Team Digna.
#
# Q happening a lot today. gop congresspeople figuring out we hate their robber-baron collusion and mean-spirited ideas.
# A I don't know .
#
# Q i have been harassed and retaliated against simply for having a conversation with this whistleblower...
# A What's the problem? What got into Nickie?
#
# Dataset cornell
# Q space stattion 5 - lounge
# A Finch. If services were stopped - at least they'd treat Iggy here with the same respect and admiration required of an Otis Lessig.
#
# Q ... we 're saved !
# retrying...
# retrying...
# A I almost sound relieved.
#
# Q ... not far , now .
# A Everything shall be alright.
#
# Q it 's okay .
# A Keep it 'til you go back.
#
# Q where 's ma ?
# retrying...
# retrying...
# retrying...
# A He don't need a ma, let go of the ma.. SAGAH.
#
# Q bravo , your majesty !
# A Yes  yes, glory, really.
#
# Q no , thank you .
# A No thank you. You want to settle down and start a family.
#
# Q your men knew the risks .
# A So if you moved out, you'd know, would you? You'd know, work with me?
#
# Q so he 's won .
# A Oh that leg.
#
# Q bad habit .
# retrying...
# retrying...
# retrying...
# A I can blow you bright red twice a day, then it's one more. A taste one thousand times better. Best cigar I've ever had. How sweet....
#
# Q for you , mrs. peel .
# A You're kidding, that's great. I can't see what Mr. Grant of course is doing here. But I do want to be friends with you  to feel the truancy of the moment.
#
# Q aren 't you coming ?
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A No, sir. You stay. Clark, phone the Consul.
#
# Q all right !
# retrying...
# retrying...
# retrying...
# A Well Kenny, we'll be a world power ..... "He" helped set the ground rules for the modern world. There are two basic forces driving the modern world. the economic forces - robotics and relativity - and the political forces - surveillance and revolution. Is there any place left for revolution today. The future of our space program is paper bomb.
#
# Q where the hell is he ?
# retrying...
# retrying...
# A Look... there are going to be people starting to wonder, Mr. Taransky. Do you think Mr. Yeltsin is up to his old tricks, or does he have a lotta nerve? How does it feel having so much pressure around you?
#
# Q what 's the matter ?
# retrying...
# retrying...
# A Wait till you go to jail - nothing you and your psychiatrist can't do.
#
# Q you 're kidding .
# A Yeah?
#
# Q that was kid gloves ?
# A That's clown rings, no fancy materials. It's come back to us, huh ?
#
# Q no bodies , no west ...
# A Hey, if you're anything like your father was, there were about sixteen thousand Indians , native man.
#
# Q why not religion , dad ?
# A Well, well, well -- but not religion, for all we know --
#
# Q she didn 't know ?
# retrying...
# retrying...
# A It's pretty impressive. Actually, I would have guessed the dead did. It might have helped or hurt.
#
# Q look again for fuck sake !
# A The one you're leaving for to the other side.
#
# Q join the party , fellas .
# A You marking any boundaries, eh ?
#
# Q yeah , you were saying ?
# retrying...
# retrying...
# A Take it easy, O'Neil. You're trying to intimidate me. Take it easy. I'm with you...
#
# Q what will you do ?
# A Why ?
#
# Q what happened to your pants ?
# A C'mon it was pants, I was making out the other bra.
#
# Q i couldn 't resist them .
# retrying...
# retrying...
# A Wow, I wonder what Tim'll do? You know, I almost figured I'd set Tim up with some money.
#
# Q i 've lived there .
# A Oh sure, Beluga. With all respect, you know that. But believe me, that's the kind of people who'd rather inhospirt a condemned landscape than a free-riding jazz organ than an old-fashioned candy cane.
#
# Q and your hand too .
# retrying...
# retrying...
# retrying...
# A But I'm a perceptive girl.
#
# Q i just want the job .
# A I'd feel terrible if he was alive.
#
# Q is that a cellar door ?
# A I have a cellar door.
#
# Q who is frank ?
# A Dorothy herself. Don't pity her that badly. Would you spare me?
#
# Q excuse me ?
# retrying...
# retrying...
# A No. But I can turn off the light, so I can see you...
#
# Q treves . well done .
# retrying...
# retrying...
# retrying...
# retrying...
# A I am going to play a trick on you and hope you change your mind. So nicely done, Paco.
#
# Q just give me a hand .
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A What are you about? Any booties?
#
# Q how 's the chicken ?
# A Everyone knows I ate very close to the plant.
#
# Q what do you think ?
# retrying...
# retrying...
# A It's gotta be women !
#
# Q where 's the medicine ?
# A Yeah, we got what's yours ? How's he trying ?
#
# Q shoot it .
# A You won't believe it.
#
# Q you all sure about this ?
# A Then what's the matter ?
#
# Q blow the goddamn hatch !
# retrying...
# retrying...
# retrying...
# A Call for help from the Captain. You can arrest him.
#
# Q why ... her ?
# retrying...
# retrying...
# A I know. I ... am I supposed to have my...?
#
# Q this feels ... incestuous .
# A What do you mean by "arcs"?
#
# Q 32 feet , six inches !
# A Fabulous. Now we both get to punch another three.
#
# Q we 're alive !
# retrying...
# retrying...
# retrying...
# A Yeah, he'll take care of him. I know much more about them.
#
# Q we 're still drifting .
# retrying...
# retrying...
# retrying...
# A NO they don't. I'll get my lances...whatever .
#
# Q another historical inaccuracy .
# A Didn't I tell you I was open-minded enough to ask some challenging questions?
#
# Q it 's almost over ! !
# A Eighteen patrons? Not one of whom should be so threatened?
#
# Q it smells damp .
# A Blood.
#
# Q where are you ?
# retrying...
# retrying...
# retrying...
# retrying...
# A Talk to me.
#
# Q first time for everything .
# A I don't want to. It's late. I'm sorry, I only made it fifteen minutes late.
#
# Q what 's wrong ?
# A Well, if I had some money to throw out if you could give me a desk here --
#
# Q where is he ?
# A Well sir, I'm an invalid - if you need my driver's license, just send them to me. I'm here, sir.
#
# Q thank you .
# retrying...
# retrying...
# retrying...
# retrying...
# A Well I --
#
# Q i 'll be in touch .
# retrying...
# retrying...
# A I'll hang up.
#
# Q who is it ?
# A There's no number.
#
# Q here , i got it .
# A 60 pages
#
# Q shoot pool , fast eddie .
# A Why you gotta play pool with junkie junkie junkie junkie junkie junkie
#
# Q your treat .
# retrying...
# retrying...
# A I like your puny hands. I can even repel a Giro d'Italia scorpion by using my sharp, plump little teeth. But Wynant is the only one in Bloomsburg who can withstand death like that. Even without me he's a donny boy. He's 10 feet tall and weighs less than one pound... buy yourself a breather!
#
# Q indy , look !
# A You know, for as long as I can remember I've never heard so much ugly stuff about you !
#
# Q anymore ideas ... ?
# A Yes
#
# Q some agent you are .
# retrying...
# retrying...
# A Armed robber? No he isn't... you realize that? Well, you have us at a unique competitive disadvantage. By concentrating on the inside, we'll each come out on top. Nobody else is going to take us out. And after you and Bobby kill this Guyanese, nobody else will get a shot at getting to us.
#
# Q who 's that ?
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A You were there last night.
#
# Q who 's she ?
# A Just enough to trace --
#
# Q every week --
# A But why PUT this in a fucking magazine? I was summarily fired.
#
# Q i don 't believe it !
# retrying...
# retrying...
# A Believe what ? I will see it all in my own mirror !
#
# Q dr. carlson 's dead ?
# A Full of holes. He was burning guns. Check 'em out. Dr. Mathison if you're interested, sir.
#
# Q can we get through these ?
# A If you say so.
#
# Q how old you ?
# retrying...
# retrying...
# A Last conversation we had, yes. Twice.
#
# Q what is it ?
# A About ain't no frame of reference. Does that mean you don't know what happened ?
#
# Q did you call ?
# retrying...
# retrying...
# A It's been called dozens of times.
#
# Q have they harmed you ?
# A I didn't be your target! I was the man with the gun. It was a day- one situation. And when you got some of these kids that don't know rights, you're never gonna learn anything. Must have scared the hell out of me. You have a responsibility to keep the guns in your custody.
#
# ...
# A Did you pull the last of that demonic shit out the locker this morning ? They must've done it in deep shit-hole !
#
# Q stanley if you don 't fuckin ' stand up and go over there i 'm gon na beat your ass --
# retrying...
# retrying...
# retrying...
# A I'm a cop.
#
# Q that must be raoul ! raoul ! look , d'artagnan 's come to visit ... ! what 's wrong ? you look awful !
# A You look awful, St. ....
#
# Q the world thinks andy kaufman sucks . so i was just giving 'em what they want ...
# A What the fuck! Dude, your punch line  you're running for public office!
#
# Q my wife 's death . i used to work in insurance , we were well covered .
# A Meaning we were somehow insured?
#
# Q there is one thing you can do for me in recognition of the death- defying risks we took to recover your product ...
# A This has never been done before.
#
# Q what am i supposed to do after i get my nails and hair done ... ?
# retrying...
# retrying...
# retrying...
# retrying...
# A I've never been the first person you hit who end up in the Marshall Asylum, but I have to say you're a helluva dedication man.
#
# Q you ain 't got a chance in hell . you need threads and glitter , baby . a front , hey ?
# A No, one of us is jus willing to risk a little risk.
#
# Q you were the one who ran around with ice in his underwear , don 't forget that .
# retrying...
# retrying...
# retrying...
# A Wilson, come on! Your time with this chickenhouse is over, and gone too. Stan impressed upon me for once and a half the more subtle qualities of an artist-in-waiting . I congratulate you, and I glory in--
#
# Q okay , meet me out front . i got ta go . josh 's picking me up in five . see you tonight .
# A ...I promise.
#
# Q evolution doesn 't work that fast . something pushed that thing to take the leap . we need to find another specimen .
# A But no guts, baby! There's plenty of other species right here .
#
# Q the order of seating at the upper servant 's table is arranged personally by the queen herself .
# A You have no idea what some people say about a king, queen, or queen like, Darius. And of course Commander Hesperides  known for his prowess in battle  I admire him  of course, my purview also carries a slight problem  corruption... Then again, anyone with a slightest touch of the Novelty could purchase the book.
#
# Q he has a phone pole sticking in his chest , i think we don 't need an autopsy .
# retrying...
# retrying...
# retrying...
# A Is something messed up?
#
# Q how do you know you can touch that plug ? are you a licensed contractor ?
# A It's a fantastic item I love it. Love it during shipping. I've found a spot that cost more than 800 - 900 bucks from Doyles. Of course they don't charge you that or anything after that. J.D - they tell you where it is. For me... You're a girl. A lot of women want that. You're so very single, you look around and they don't know you. You are. I miss it. So you play at it. You're unique.
#
# Q it 's my dad . he worries . hi , dad . i miss you too .
# A I miss you like a mother.
#
# Q do you mind me not saying -- it 's a rather distressing disease and the name of the hospital rather gives it away .
# A Is it intense?
#
# Q so what 's that mean ? that you 're disappointed by what you found or you 're sorry you robbed all those banks ?
# A NO ... I am so sorry for what I robbed --
#
# Q yeah , someone spotted two of 'em in this hobo camp out by the airport , called the number --
# A Hello, Malcolm. Are you there for me or aren't you?
#
# Q when i was young i thought cats were the girls and dogs were the boys .
# retrying...
# retrying...
# A Who lived in Harlem?
#
# Q no juice , looks like it 's been laid up for years . but we might be able to adapt --
# A -- we want to throw away a little cash for the right stuff
#
# Q amazing how you can do without the essentials of life -- so long as you have the luxuries .
# A Max: I need to get some sleep -- I don't feel well -- I've got rashes -- I've thought about getting a bad toothbrush -- What kind of life are we talking about?
#
# Q he 'll be looking for the trip wires . if we 're lucky , he won 't see this .
# A Thanks
#
# Q aren 't you going to take the pills ? they 'll knock that headache out .
# A Yeah, sure.
#
# Q hasn 't he got enough problems , or didn 't you notice that 's not cream soda on his breath ?
# retrying...
# retrying...
# A An' ? Look --
#
# Q what do you want ? i 'm clean . i been clean a long time .
# A What are you doing someplace ?
#
# Q this much powder you don 't throw in the trunk with a blanket over it . it 's got to be smuggled .
# A You really expect me to think it all gets crammed together in two extra trunk bunks with a blanket over it?
#
# Q i see . so this wasn 't simply a chance meeting . you came here with a purpose .
# A Not sure how . . .
#
# Q because if they had she 'd be gone along with the package , instead of sitting here with us .
# A Ssh, is all this supposed to make me feel better?
#
# Q all right hold on ! lem me think ... shit , did you touch the car ?
# A Would you give us your word that ... ?
#
# Q is that what i did to you ? is that what happened ? did i just not see you ?
# retrying...
# retrying...
# A Yeah. We all did, I swear to you.
#
# Q i 've been making friends with your cat . is it okay that i 'm here ?
# retrying...
# retrying...
# retrying...
# A Shelly, you're dying!!! You can't be living with me. I love her! ...God, Vic, look at her! LOVIN' HER AND LET US FUCK HER OVER HER FING BITCH!
#
# Q this is a complete disaster . i wanted him to find a wife , but he 's got the wrong one --
# retrying...
# retrying...
# A I know! How do you know? Do you know the toothpaste I bought him? Do you know the way he uses that hand ?
#
# Q so they had a little taste of what its like to be a woman ... and they run away .
# A Mr Rothstein, we haven't heard from him!
#
# Q reiben , how many time i got to tell you , i 'm from tennessee .
# A Alan, you're gonna want to get to know the bounty hunter part too. James Tynion.
#
# Q i know about bracketing . i read about it . the next one is going to land right on us .
# retrying...
# retrying...
# A Wait a minute. What's going to affect the next one?
#
# Q hey , i know this is a strange thing to say , but maybe diane court really likes lloyd .
# retrying...
# retrying...
# A She likes him.
#
# Q i couldnt believe you didnt recognize me . you even interviewed me for your book .
# A Suppose youre a sales rep doing things to women?
#
# Q that 's fine mr. rielly , but if anyone else should die , i 'm going to have to get a warrant .
# A Sir?
#
# Q tell that to cotton weary . you wouldn 't believe how easy it was to frame him .
# retrying...
# retrying...
# retrying...
# retrying...
# A He isn't. You're going to tell me .
#
# Q i wan na see jamie lee 's breasts . when do we see jamie lee 's breasts ?
# A ' rapo. Jello!
#
# Q hey , sid . just think if they make a movie about you . who 's gon na play you ?
# A Donna's gonna see ya gut tries on a leg...
#
# Q there 's that sense of humor . i knew it still existed . ohh , sid , let 's have some fun tonight .
# A It's the main course. Everyone else here is doing their duty, which means...
#
# Q killed every one -- an ' not for food either ... why 'd they do a thing like that ?
# A He may turn out to be a little way off, but have death come for you ? Aren't you going to make yourself a drink ?
#
# Q my name 's edwards ... i 'm looking for my niece ... she was in that camp when you attacked ...
# A Well she's gettin' no death threats yet ... they tell me she's an Indian ... just the two o's ... Go away. Go ahead ... it won't do you any good to go on havin' a bad day.
#
# Q now i said i had something for you , as i believe you will recall .
# retrying...
# retrying...
# A What?
#
# Q i thought i heard voices - and i just had to talk to somebody . i don 't feel like going to sleep .
# A Wait a minute. Your husband sounds so...
#
# Q you know , they say you can tell everything you need to know about a person from the way they act when theyre naked .
# retrying...
# retrying...
# A Buddy. That's what I am.
#
# Q look . we 're talking about life and death here . i don 't know why we 're even having this conversation .
# A No we don't .and it isn't any good .
#
# Q your pop said to put these on his tab . sid gets up and jerks his thumb towards the door .
# A You got lucky with the phone.
#
# Q oh sure . let everyone in . from now on i leave the door wide open . let the parade begin !
# retrying...
# retrying...
# A Yeah, but  also  it's early.
#
# Q these aren 't half bad , fletcher . you might have a second career coming .
# A Stay home real fast Eddie . . . hey, I think it's a reasonably good idea . . . you know, things have worked out perhaps already . . . But excuse me . . . Leno cutting me out for a second, okay?
#
# Q i noticed you were having some problems , blue five ... i thought i 'd help .
# A What kind of problems is that?
#
# Q it 's amazing , us running into each other like this . maybe it 's fate .
# A Do you still smoke?
#
# Q we 're outa here . lieutenant , get your men into the skimmers . this real estate 's about to go buggy .
# A Virmire d'hyzer l'ingolland lad, ye're not leaving till everyone dies. I had to kill every cowardly little negroid I met - every rotten little cinnamon - because ya pour down one ugly dime that hits out- ONE HUNDRED every negroid and with it resides my mission. And if some squirtin' maniac got those POW credentials off ye can kill me with them! I'11 have an ass out foot! Invite me in a pot-luck dinner  anything  grilled fish, amateur rib roast, hambone ciabatta, steamed duck, or fried pig's head stew! That's what ya doin', pal. I bring ya rice, beans, spaghetti, beans, and rice! Y'all conquer the poverty in Mexico? Don't forget to expand education in welfare...? thank you.
#
# Q rico , tell'em to glass this goddam planet . i 've never seen so many bugs upstairs at the same time ...
# A You a human, Ray?
#
# Q i have an appointment this after- noon . i need someone to take them to the park .
# A I'm sorry.
#
# Q mom , it 's not fair if brady can say the f-word and i can 't .
# A In the darkest moments she talks hope.
#
# Q if you reach for the stars , you 're bound to get -- mm-jack , pull over .
# A O-kay.
#
# Q look , maybe i can watch a pg movie ... i 'll just say i 'm counting dirty words for sunday school .
# retrying...
# retrying...
# A I'm just jokin' in my sleep, Billy. Which one of you is your sleeping buddy? I like us some very much.
#
# Q hiya , sweet thing . little guy 's getting ' hassled , huh ? kent , you still here ?
# A Relax . Leave the room. I walked onto the marquis 'LL, then came home after .. Well dry-cleaning and cleaning the car and opening a couple of cans of cans of cans of beer.
#
# Q you ! activate circuits 29 through w7 and start full power coordinates on exterior defensive systems :
# A Silent !
#
# Q that 's what i want to know ! by whom ? whom ? ? ? ?
# retrying...
# retrying...
# A CLOSE  You've got people going through your hair this and that  remember?
#
# Q and she -- the one you have chosen -- she feels as much for you ?
# A Why her? Why should I feel for her? <u>She</u> <u>knows nothing</u>. She cuddles you.
#
# Q here 's the story on that east 19th street murder spree . page one with a banner headline seems about right to me .
# A Does it mention Deirdre?
#
# Q you 're already dead , silberman . everybody here dies . you know i believe that . so don 't fuck with me !
# A Lily --
#
# Q no , i was never a nazi , i have no interest in politics , i 'm a musician -
# retrying...
# retrying...
# A that chisholm sismete , that music the name of this place says.
#
# Q i only mention it because i took the test this afternoon , down on montgomery street .
# A Yeah? Can't Amish girls use the street? Like so?
#
# Q all the time i 've known you , you 've never once asked about him .
# A No you never asked about him you never asked about me, I have nothing you might retrieve from me. I stick to the shell cores and your broken down patch, I always tell the truth .
#
# Q i 've lived in l.a. all my life , i 've never done this drive .
# retrying...
# retrying...
# A I am mad 'at.
#
# Q it 's been five minutes and i 'm packing to leave again . i can 't believe this .
# retrying...
# retrying...
# retrying...
# A You want our car's worth five hundred thousand?
#
# Q what if he wasn 't like this ? what if he was `` normal ? '' conscious . how far would you go ?
# A You'd go a lot of places.
#
# Q but , danny , if hashem is everything , and we are nothing how are we to judge his actions ?
# A Missus Mikkelson --
#
# Q danny , listen , people expect me to daven ; they don 't want someone they don 't know -- leading their prayers .
# A But I've got friends in the house .
#
# Q im sorry but mr gluck is not answering , sir . would you like to leave a message ?
# retrying...
# retrying...
# A Just put down your valise . You hear ?
#
# Q it is the sacred place that matters , charles -- not the size . am i correct , bishop ?
# retrying...
# retrying...
# A No. This is for your satisfaction, by the way. In this song and dance, this region and maidens are always united.
#
# Q it is for us to determine whether you are a good christian , not you .
# A I do not know what I am or as God here calls us, I do not know if you are christ, or Jews as it is in the Jewish religion.
#
# Q no , no , no , i 'm staying put . if i 'm going to die , i prefer to die at home .
# A I've gotle asked Katie not to .
#
# Q we can head back for our lines , and they don 't even have to know about the gold .
# retrying...
# retrying...
# retrying...
# A You have the risks but I have the rewards.
#
# Q well , this is it . we get the car , find some americans . we find americans we 'll be all right .
# retrying...
# retrying...
# retrying...
# A We got lost , Rudy.
#
# Q the longer the air force hits the iraqis , the safer it'ii be for us when we have to engage .
# A And their defence will be so reduced that it wouldn't be likely that they could rely on missiles like that in the first place?
#
# Q this one has eyes . why did they leave your eyes ? could you ever ... .
# retrying...
# retrying...
# A A doubt still lingers.
#
# Q i believe you are blushing , mr. big artiste . i can 't imagine monsieur monet blushing .
# A Good, now turn around some more and I mean to tell you how terrible your parents' car accident got to me .
#
# Q thought you might need me -- don 't talk , kid , and don 't let him scare you --
# A Don't threaten me , makin' out.
#
# Q i calculate that 's the end of this town . and let 's don 't bother about the luggage , darling .
# retrying...
# retrying...
# retrying...
# A You mean it was luggage !
#
# Q by the way - what is it that brings you to kuala lumpur , mister bond ?
# A Don't fight with that - I want to talk to you on your way out.
#
# Q hocker 's death almost caused a race riot . a lot of innocent people could have been hurt behind that .
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A You said it wasn't about the riot .
#
# Q i need you to talk to dana . the vice principle called and she cut class again this afternoon .
# A Get your boots on! --
#
# Q look , i know you 're upset . i 'm really sorry , honey . i raced home as quick --
# A How's he?
#
# Q ... you should have seen your father , standing there all covered with spaghetti sauce . he looked like such a dope .
# A I wouldn't want to get carried away.
#
# Q look , i don 't know this is pretty heavy-duty , so if you wan na explode , feel free .
# retrying...
# retrying...
# A Why'd you smack me?
#
# Q john , what a surprise . i expected to be seeing you , not talking to you over the phone .
# A What's wrong!
#
# Q we 're going to prevent any substantial atrophy of your good leg with this . it works the quadriceps .
# A Proceed with the damage.
#
# Q it 's okay ... it 's okay baby . cry for mama . cry for mama .
# retrying...
# retrying...
# retrying...
# retrying...
# A Linda ...
#
# Q i need to know what snapped in you . what made you capable of it . you have to make me understand .
# A Oh baby, you scared me so bad you made me stupid . Stupid is nothing but a way of thinking that scares you, your crazy mother .
#
# Q rowan and i will be together now . my time has come . your time is gone .
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# retrying...
# A What time is it?
#
# Q we can 't accept it . it 's much too expensive . right , dear ?
# A If we accept this, its very cheap.
